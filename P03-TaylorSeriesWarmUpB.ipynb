# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s=1.0
x=linspace(1.03,1.2,100)
Uo=1.0

U=Uo*((s/x)**12-(s/x)**6)

plot(x,U)

# %%
x0=2**(1/6)*s
k=9*2**(2/3)*Uo/s**2

Ut=-Uo/4.0 + 0.5*k*(x-x0)**2
plot(x,Ut,'g-')
plot(x,U,'r-')

# %%
linspace?
