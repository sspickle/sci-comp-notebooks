# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as pl

# %%
df = pd.read_csv('dimitris2.csv')
df.head()
# Out:
#     time  angle
# 0  0.000    0.0
# 1  0.001    0.0
# 2  0.002    0.0
# 3  0.003    0.0
# 4  0.004    0.0

# %%
pl.plot(df.time, df.angle)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
time = df.time[(df.time>10.5) & (df.time < 17.5)]
angle = df.angle[(df.time>10.5) & (df.time < 17.5)]
pl.plot(time,angle,'b.')
