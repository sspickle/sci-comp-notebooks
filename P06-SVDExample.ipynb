# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from PIL import Image

# %%
img = Image.open('imgs/einst.png')
imggray = img.convert('LA')
imggray.size, imggray.size[0]*imggray.size[1]
# Out:
# ((239, 303), 72417)

# %%
imgmat = np.array(list(imggray.getdata(band=0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
#imgmat = np.matrix(imgmat)
plt.figure(figsize=(9,6))
plt.imshow(imgmat, cmap='gray');

# %%
U, sigma, V = np.linalg.svd(imgmat)
print(U.shape, sigma.shape, V.shape)
# Out:
# (303, 303) (239,) (239, 239)

# %%
print(U[:, :1].shape, sigma[:1].shape, V[:1, :].shape)
# Out:
# (303, 1) (1,) (1, 239)

# %%
reconstimg = (U[:, :1]) @ np.diag(sigma[:1]) @ V[:1, :]
plt.imshow(reconstimg, cmap='gray');

# %%
for i in range(2, 10):
    reconstimg = U[:, :i] @ np.diag(sigma[:i]) @ V[:i, :]
    plt.imshow(reconstimg, cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()

# %%
for i in range(10, 51, 5):
    reconstimg = U[:, :i] @ np.diag(sigma[:i]) @ V[:i, :]
    plt.imshow(reconstimg, cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c907b365-004f-4e4b-9b82-10049ee80d2d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
